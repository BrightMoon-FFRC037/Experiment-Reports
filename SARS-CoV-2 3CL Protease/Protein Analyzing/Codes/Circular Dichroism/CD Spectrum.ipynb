# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('Spectrum.xlsx')
data
# Out:
#      wave_blank  ellipticity_blank  wave_0  ellipticity_0  wave_1.2  \
# 0           190          -3.542000     190      -4.927510       190
# 1           191          -1.949840     191      -5.752080       191
# 2           192          -0.804662     192      -7.371710       192
# 3           193          -0.047449     193      -9.050780       193
# 4           194           0.380828     194     -11.358800       194
# ..          ...                ...     ...            ...       ...
# 146         336          -0.039268     336       0.261950       336
# 147         337          -0.034697     337       0.209142       337
# 148         338          -0.016714     338       0.235611       338
# 149         339           0.016104     339       0.271052       339
# 150         340           0.065179     340       0.371344       340
#
#      ellipticity_1.2  wave_2.4  ellipticity_2.4  wave_3.6  ellipticity_3.6  \
# ...

# %%
x=data['wave_blank']
y=data['ellipticity_blank']
plt.plot(x,y)

# %%
lst = ['0','1.2','2.4','3.6','4.8','6']
for i in lst:
    x=data['wave_'+f'{i}']
    y=data['ellipticity_'+f'{i}']
    plt.plot(x,y,label=f'c(guanidine)={i}M')
plt.legend()
plt.xlabel('wavelength (nm)')
plt.ylabel('CD absorbance, ellipticity (mdeg)')
# Out:
# Text(0, 0.5, 'CD absorbance, ellipticity (mdeg)')

# %%
lst = ['0','1.2','2.4','3.6','4.8','6']
for i in lst:
    x=data['wave_'+f'{i}']
    y=data['ellipticity_'+f'{i}']
    plt.plot(x,y,label=f'c(guanidine)={i}M')
plt.legend()
plt.xlim(220,260)
plt.ylim(-80,-30)
# Out:
# (-80.0, -30.0)
