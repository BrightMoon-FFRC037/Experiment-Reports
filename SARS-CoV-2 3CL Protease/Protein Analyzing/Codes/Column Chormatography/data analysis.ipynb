# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('./Affinity Column-B Concentration.xlsx')
volume = np.array(data['ml'])
y = np.array(data['c(B)'])
plt.plot(volume,y,label='B Percentage')
plt.xlabel('Volume (mL)')
plt.ylabel('Percentage of Buffer B (%)')
plt.legend()
ax_1 = plt.gca().twinx()
data_1 = pd.read_excel('./Affinity Column-UV and Conductance.xlsx')
volume_1 = np.array(data_1['ml_UV'])
y = np.array(data_1['mAU'])
ax_1.plot(volume_1,y,color='orange',label='UV Absorbance')
plt.ylabel('280 nm UV Absorbance (mAU)')
plt.legend()
plt.ylim(-200,3700)
# Out:
# (-200.0, 3700.0)

# %%
data = pd.read_excel('./Affinity Column-B Concentration.xlsx')
volume = np.array(data['ml'])
y = np.array(data['c(B)'])
plt.plot(volume,y,label='B Percentage')
plt.xlabel('Volume (mL)')
plt.ylabel('Percentage of Buffer B (%)')
plt.legend()
ax_1=plt.gca().twinx()
data = pd.read_excel('./Affinity Column-UV and Conductance.xlsx')
volume = np.array(data['ml_Cond'])
y = np.array(data['mS/cm'])
ax_1.plot(volume,y,color='orange',label = 'Conductance')
plt.xlabel('Volume (mL)')
plt.ylabel('Conductance (mS/cm)')
plt.legend()

# %%
data = pd.read_excel('./Affinity Column-UV.xlsx')
volume = np.array(data['ml'])
y = np.array(data['mAU'])
plt.plot(volume,y)
plt.xlabel('Volume (mL)')
plt.ylabel('280 nm UV Absorbance (mAU)')
# Out:
# Text(0, 0.5, '280 nm UV Absorbance (mAU)')

# %%
data = pd.read_excel('./Filtration Column.xlsx')
volume = np.array(data['ml Conc B'])
y = np.array(data['%'])
plt.plot(volume,y,label='B Percentage')
plt.xlabel('Volume (mL)')
plt.ylabel('Percentage of Buffer B (%)')
plt.legend()
ax_1=plt.gca().twinx()
x = np.array(data['ml UV 280'])
y = np.array(data['mAU'])
ax_1.plot(x,y,color='orange',label='UV Absorbance')
plt.ylabel('280 nm UV Absorbance (mAU)')
plt.legend()
plt.xlim((-2,20))
# Out:
# (-2.0, 20.0)

# %%
x = np.array(data['ml UV 280_CUT'])
y = np.array(data['mAU_cut'])
plt.plot(x,y)

# %%
data = pd.read_excel('./Filtration Column.xlsx')
volume = np.array(data['ml Conc B'])
y = np.array(data['%'])
plt.plot(volume,y,label='B Percentage')
plt.xlabel('Volume (mL)')
plt.ylabel('Percentage of Buffer B (%)')
plt.legend()
ax_1=plt.gca().twinx()
x = np.array(data['ml Cond'])
y = np.array(data['mS/cm'])
ax_1.plot(x,y,color='orange',label='Conductance')
plt.ylabel('Conductance (mS/cm)')
plt.legend()
plt.xlim((-2,20))
# Out:
# (-2.0, 20.0)

# %%
x = np.array(data['ml UV 280'])
y = np.array(data['mAU'])
plt.plot(x,y,label='UV Absorbance')
plt.ylabel('280 nm UV Absorbance (mAU)')
plt.xlabel('Volume (mL)')
plt.legend(loc='upper left')
ax_1=plt.gca().twinx()
x = np.array(data['ml Cond'])
y = np.array(data['mS/cm'])
ax_1.plot(x,y,color='orange',label='Conductance')
plt.ylabel('Conductance (mS/cm)')
plt.xlabel('Volume (mL)')
plt.legend()

plt.xlim((-2,20))
# Out:
# (-2.0, 20.0)
